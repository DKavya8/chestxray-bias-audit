# %% [markdown]
# <a href="https://colab.research.google.com/github/DKavya8/chestxray-bias-audit/blob/main/notebooks/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf chestxray-bias-audit
# !git clone https://github.com/DKavya8/chestxray-bias-audit.git
# %cd chestxray-bias-audit
# Out:
# Cloning into 'chestxray-bias-audit'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 30 (delta 9), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (30/30), 10.84 KiB | 10.84 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/chestxray-bias-audit/chestxray-bias-audit

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q -r requirements.txt

# %%
import numpy; print(numpy.__version__)
# Out:
# 2.0.2

# %%
# !cat requirements.txt
# Out:
# torchxrayvision==1.5.2
# pydicom==3.0.2
# numpy==2.0.2
# pandas==2.2.2

# %%
import os, torch
print("torch version:", torch.__version__)

import torchxrayvision as xrv
model = xrv.models.DenseNet(weights="densenet121-res224-all")
print("Everything loaded — setup complete.")

with open("/content/drive/MyDrive/team-RACK-bias-paper/results/lockfile.txt", "w") as f:
    f.write(os.popen("pip freeze").read())
print("Saved exact version list.")
# Out:
# torch version: 2.11.0+cu128
# Everything loaded — setup complete.
# Saved exact version list to Drive.
